# %%
from sqlitesearch import TextSearchIndex

sqlite_index = TextSearchIndex(
    text_fields=['question', 'section', 'answer'],
    keyword_fields=['course'],
    db_path='faq.db'
)

# %%
from dotenv import load_dotenv
load_dotenv()

from anthropic import Anthropic
anthropic_client = Anthropic()

# %%
from rag_helper import RAGBase

assistant = RAGBase(sqlite_index, anthropic_client)

# %%
assistant.rag('I just discovered the course, can I still join?')
# Out:
# '# Answer\n\nYes, you can still join the course! \n\nHowever, there\'s an important thing to keep in mind: **if you want to receive a certificate, you need to submit your project while submissions are still being accepted**.\n\nFor the certificate, you\'ll need to:\n- Complete the course with the "live" cohort (self-paced mode doesn\'t qualify for certificates)\n- Submit your Capstone project before the deadline\n- Peer-review 3 other capstone projects (this can only be done while the course is running)\n\nThe good news is that homework is not mandatory for the certificate - you only need to pass the Capstone project. However, homework is recommended as it helps reinforce the concepts you\'re learning.'
