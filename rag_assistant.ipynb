# %%
from rag_helper import RAGBase
from ingest import load_faq_data, build_index

# %%
from dotenv import load_dotenv
load_dotenv()

from anthropic import Anthropic
anthropic_client = Anthropic()

# %%
documents = load_faq_data()
index = build_index(documents)

assistant = RAGBase(index, anthropic_client)

# %%
assistant.rag('I just discovered the course, can I still join?')
# Out:
# '# Answer\n\n**Yes, you can still join the course!** \n\nHowever, there\'s an important condition if you want to receive a certificate: **you need to submit your project while submissions are still being accepted.**\n\nA few additional points to keep in mind:\n\n- You don\'t need to wait for a confirmation email - you\'re automatically accepted and can start learning right away\n- Registration is just to gauge interest; you can submit homework without being on any registered list (while the form is open)\n- To get a certificate, you must complete the course with a "live" cohort, not in self-paced mode\n- Certificate requirements include submitting the Capstone project and peer-reviewing 3 other capstone projects\n\nSo feel free to jump in and start learning! Just make sure to complete your project submission before the deadline if you want to earn a certificate.'
